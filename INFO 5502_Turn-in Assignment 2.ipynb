# %% [markdown]
# # Turn-in Assignment - 2

# %%
import pandas as pd

# load employee dataset into a Pandas DataFrame
df = pd.read_csv('employee.csv')

# print the first 5 rows of the DataFrame
print(df.head())

# calculate descriptive statistics of the DataFrame
print(df.describe())
# Out:
#    UNIQUE_ID               POSITION_TITLE                     DEPARTMENT  \
# 0          0  ASSISTANT DIRECTOR (EX LVL)    Municipal Courts Department
# 1          1            LIBRARY ASSISTANT                        Library
# 2          2               POLICE OFFICER  Houston Police Department-HPD
# 3          3            ENGINEER/OPERATOR  Houston Fire Department (HFD)
# 4          4                  ELECTRICIAN    General Services Department
#
#    BASE_SALARY             RACE EMPLOYMENT_TYPE  GENDER EMPLOYMENT_STATUS  \
# 0     121862.0  Hispanic/Latino       Full Time  Female            Active
# 1      26125.0  Hispanic/Latino       Full Time  Female            Active
# 2      45279.0            White       Full Time    Male            Active
# 3      63166.0            White       Full Time    Male            Active
# 4      56347.0            White       Full Time    Male            Active
#
#    HIRE_DATE    JOB_DATE
# 0  6/12/2006  10/13/2012
# 1  7/19/2000   9/18/2010
# ...

# %%
# print the data of each row and column
import csv
file=open('/Users/narendranathreddy/Desktop/5502/Assignment 2 /employee.csv','r')
data=list(csv.DictReader(file,delimiter=","))
file.close()
print(data)
# Out:
# [{'UNIQUE_ID': '0', 'POSITION_TITLE': 'ASSISTANT DIRECTOR (EX LVL)', 'DEPARTMENT': 'Municipal Courts Department', 'BASE_SALARY': '121862', 'RACE': 'Hispanic/Latino', 'EMPLOYMENT_TYPE': 'Full Time', 'GENDER': 'Female', 'EMPLOYMENT_STATUS': 'Active', 'HIRE_DATE': '6/12/2006', 'JOB_DATE': '10/13/2012'}, {'UNIQUE_ID': '1', 'POSITION_TITLE': 'LIBRARY ASSISTANT', 'DEPARTMENT': 'Library', 'BASE_SALARY': '26125', 'RACE': 'Hispanic/Latino', 'EMPLOYMENT_TYPE': 'Full Time', 'GENDER': 'Female', 'EMPLOYMENT_STATUS': 'Active', 'HIRE_DATE': '7/19/2000', 'JOB_DATE': '9/18/2010'}, {'UNIQUE_ID': '2', 'POSITION_TITLE': 'POLICE OFFICER', 'DEPARTMENT': 'Houston Police Department-HPD', 'BASE_SALARY': '45279', 'RACE': 'White', 'EMPLOYMENT_TYPE': 'Full Time', 'GENDER': 'Male', 'EMPLOYMENT_STATUS': 'Active', 'HIRE_DATE': '2/3/2015', 'JOB_DATE': '2/3/2015'}, {'UNIQUE_ID': '3', 'POSITION_TITLE': 'ENGINEER/OPERATOR', 'DEPARTMENT': 'Houston Fire Department (HFD)', 'BASE_SALARY': '63166', 'RACE': 'White', 'EMPLOY
# ...

# %%
# print information about dataset
employee_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   UNIQUE_ID          2000 non-null   int64
#  1   POSITION_TITLE     2000 non-null   object
#  2   DEPARTMENT         2000 non-null   object
#  3   BASE_SALARY        1886 non-null   float64
#  4   RACE               1965 non-null   object
#  5   EMPLOYMENT_TYPE    2000 non-null   object
#  6   GENDER             2000 non-null   object
#  7   EMPLOYMENT_STATUS  2000 non-null   object
#  8   HIRE_DATE          2000 non-null   object
#  9   JOB_DATE           1997 non-null   object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 156.4+ KB

# %%
# print size of dataset
employee_df.shape
# Out:
# (2000, 10)

# %%
# print data types of each column
print(employee_df.dtypes)
# Out:
# UNIQUE_ID              int64
# POSITION_TITLE        object
# DEPARTMENT            object
# BASE_SALARY          float64
# RACE                  object
# EMPLOYMENT_TYPE       object
# GENDER                object
# EMPLOYMENT_STATUS     object
# HIRE_DATE             object
# JOB_DATE              object
# dtype: object

# %%
# print missing values of each column
employee_df.isna().sum()
# Out:
# UNIQUE_ID              0
# POSITION_TITLE         0
# DEPARTMENT             0
# BASE_SALARY          114
# RACE                  35
# EMPLOYMENT_TYPE        0
# GENDER                 0
# EMPLOYMENT_STATUS      0
# HIRE_DATE              0
# JOB_DATE               3
# dtype: int64

# %%
# print the total position tittles in dataset
depts=employee_df['POSITION_TITLE'].unique()
print(depts)
# Out:
# ['ASSISTANT DIRECTOR (EX LVL)' 'LIBRARY ASSISTANT' 'POLICE OFFICER'
#  'ENGINEER/OPERATOR' 'ELECTRICIAN' 'SENIOR POLICE OFFICER' 'ENGINEER'
#  'CARPENTER' 'DEPUTY ASSISTANT DIRECTOR (EXECUTIVE LEV'
#  'AIRPORT OPERATIONS COORDINATOR' 'FIRE FIGHTER' 'CHIEF PHYSICIAN,MD'
#  'CUSTOMER SERVICE REPRESENTATIVE I'
#  'PUBLIC HEALTH INVESTIGATOR SUPERVISOR' 'POLICE SERGEANT'
#  'MAINTENANCE MECHANIC III' 'SENIOR INSPECTOR' 'INSPECTOR'
#  'UTILITY WORKER' 'FIRE FIGHTER TRAINEE' 'SENIOR ACCOUNTANT'
#  'DENTAL ASSISTANT' 'ASSISTANT SHOP MANAGER'
#  'SENIOR MICROCOMPUTER ANALYST' 'INVENTORY MANAGEMENT SUPERVISOR'
#  'ASSOCIATE EMS PHYSICIAN DIRECTOR' 'FIELD SUPERVISOR'
#  'CUSTOMER SERVICE SUPERVISOR' 'CAPTAIN' 'DIVISION MANAGER'
#  'ADMINISTRATIVE ASSOCIATE' 'SEMI-SKILLED LABORER'
#  'EQUIPMENT OPERATOR III' 'LABORER' 'EQUIPMENT WORKER'
#  'IT PROJECT MANAGER' 'AIRPORT OPERATIONS SPECIALIST'
#  'PUBLIC HEALTH DENTIST,DDS' 'CUSTOMER SERVICE CLERK'
# ...

# %%
# print unique values in each column
unique_values=employee_df.nunique (axis=0)
print (unique_values)
# Out:
# UNIQUE_ID            2000
# POSITION_TITLE        330
# DEPARTMENT             24
# BASE_SALARY           791
# RACE                    6
# EMPLOYMENT_TYPE         5
# GENDER                  2
# EMPLOYMENT_STATUS       2
# HIRE_DATE             999
# JOB_DATE              947
# dtype: int64

# %%
dept='Library'
for i in range(len(data)):
    print(data[i])
# Out:
# {'UNIQUE_ID': '0', 'POSITION_TITLE': 'ASSISTANT DIRECTOR (EX LVL)', 'DEPARTMENT': 'Municipal Courts Department', 'BASE_SALARY': '121862', 'RACE': 'Hispanic/Latino', 'EMPLOYMENT_TYPE': 'Full Time', 'GENDER': 'Female', 'EMPLOYMENT_STATUS': 'Active', 'HIRE_DATE': '6/12/2006', 'JOB_DATE': '10/13/2012'}
# {'UNIQUE_ID': '1', 'POSITION_TITLE': 'LIBRARY ASSISTANT', 'DEPARTMENT': 'Library', 'BASE_SALARY': '26125', 'RACE': 'Hispanic/Latino', 'EMPLOYMENT_TYPE': 'Full Time', 'GENDER': 'Female', 'EMPLOYMENT_STATUS': 'Active', 'HIRE_DATE': '7/19/2000', 'JOB_DATE': '9/18/2010'}
# {'UNIQUE_ID': '2', 'POSITION_TITLE': 'POLICE OFFICER', 'DEPARTMENT': 'Houston Police Department-HPD', 'BASE_SALARY': '45279', 'RACE': 'White', 'EMPLOYMENT_TYPE': 'Full Time', 'GENDER': 'Male', 'EMPLOYMENT_STATUS': 'Active', 'HIRE_DATE': '2/3/2015', 'JOB_DATE': '2/3/2015'}
# ...

# %%
# print rows that has department as Houston Police Department-HPD
dept='Houston Police Department-HPD'
for i in range(len(data)):
    if data[i]['DEPARTMENT'] == dept:
        print(data[i])
    else:
        continue
# Out:
# {'UNIQUE_ID': '2', 'POSITION_TITLE': 'POLICE OFFICER', 'DEPARTMENT': 'Houston Police Department-HPD', 'BASE_SALARY': '45279', 'RACE': 'White', 'EMPLOYMENT_TYPE': 'Full Time', 'GENDER': 'Male', 'EMPLOYMENT_STATUS': 'Active', 'HIRE_DATE': '2/3/2015', 'JOB_DATE': '2/3/2015'}
# {'UNIQUE_ID': '5', 'POSITION_TITLE': 'SENIOR POLICE OFFICER', 'DEPARTMENT': 'Houston Police Department-HPD', 'BASE_SALARY': '66614', 'RACE': 'Black or African American', 'EMPLOYMENT_TYPE': 'Full Time', 'GENDER': 'Male', 'EMPLOYMENT_STATUS': 'Active', 'HIRE_DATE': '11/26/1984', 'JOB_DATE': '3/26/2005'}
# {'UNIQUE_ID': '14', 'POSITION_TITLE': 'POLICE SERGEANT', 'DEPARTMENT': 'Houston Police Department-HPD', 'BASE_SALARY': '77076', 'RACE': 'Black or African American', 'EMPLOYMENT_TYPE': 'Full Time', 'GENDER': 'Male', 'EMPLOYMENT_STATUS': 'Active', 'HIRE_DATE': '6/4/2001', 'JOB_DATE': '5/25/2015'}
# ...

# %%
# imporing libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.read_csv('/Users/narendranathreddy/Desktop/5502/Assignment 2 /employee.csv')
  
employee_df = pd.DataFrame(data)
  
X = list(employee_df.iloc[:, 0])
Y = list(employee_df.iloc[:, 1])
  
# Plot the data using bar() method
plt.bar(X, Y, color='g')
plt.xlabel("RACE")
plt.ylabel("GENDER")
  
# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load dataset
data = pd.read_csv('/Users/narendranathreddy/Desktop/5502/Assignment 2 /employee.csv')

# Create scatter plot
sns.scatterplot(x="GENDER", y="RACE", data=data)

# Show plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load dataset
data = pd.read_csv('/Users/narendranathreddy/Desktop/5502/Assignment 2 /employee.csv')

# Create line plot
sns.lineplot(x="GENDER", y="RACE", hue="BASE_SALARY", data=data)

# Show plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load dataset
data = pd.read_csv('/Users/narendranathreddy/Desktop/5502/Assignment 2 /employee.csv')

# Create bar plot
sns.barplot(x="BASE_SALARY", y="RACE", hue="GENDER", data=data)

# Show plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load dataset
data = pd.read_csv('/Users/narendranathreddy/Desktop/5502/Assignment 2 /employee.csv')

# Create violin plot
sns.violinplot(x="RACE", y="BASE_SALARY", hue="GENDER", data=data, split=True)

# Show plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load dataset
data = pd.read_csv('/Users/narendranathreddy/Desktop/5502/Assignment 2 /employee.csv')

# Create box plot
sns.boxplot(x="GENDER", y="BASE_SALARY", data=data)

# Show plot
plt.show()

# %%
import seaborn as sns

# Load dataset
data = pd.read_csv('/Users/narendranathreddy/Desktop/5502/Assignment 2 /employee.csv')

# Create pair plot
sns.pairplot(data, hue="GENDER")

# Show plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load dataset
data = pd.read_csv('/Users/narendranathreddy/Desktop/5502/Assignment 2 /employee.csv')

# Create facet grid
g = sns.FacetGrid(data, col="GENDER", row="GENDER")
g.map(sns.scatterplot, "GENDER", "RACE")

# Show plot
plt.show()

# %%
import seaborn as sns

# Load dataset
data = pd.read_csv('/Users/narendranathreddy/Desktop/5502/Assignment 2 /employee.csv')

# Create strip plot
sns.stripplot(x="DEPARTMENT", y="RACE", hue="GENDER", data=data)

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py in convert_units(self, x)
#    1505         try:
# -> 1506             ret = self.converter.convert(x, self.units, self)
#    1507         except Exception as e:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/category.py in convert(value, unit, axis)
#      67         # force an update so it also does type checking
# ---> 68         unit.update(values)
#      69         return np.vectorize(unit._mapping.__getitem__, otypes=[float])(values)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/category.py in update(self, data)
#     226             # OrderedDict just iterates over unique values in data.
# --> 227             _api.check_isinstance((str, bytes), value=val)
#     228             if convertible:
#
# ...

# %%
import seaborn as sns

# Load dataset
data = pd.read_csv('/Users/narendranathreddy/Desktop/5502/Assignment 2 /employee.csv')

# Create joint plot
sns.jointplot(x="BASE_SALARY", y="RACE", data=data)

# Show plot
plt.show()
